# %%
# Provides ways to work with large multidimensional arrays
import numpy as np 
# Allows for further data manipulation and analysis
import pandas as pd 
import matplotlib.pyplot as plt # Plotting
import matplotlib.dates as mdates # Styling dates
# %matplotlib inline

# pip install numpy
# conda install -c anaconda pandas
# conda install -c conda-forge matplotlib

import datetime as dt # For defining dates

import time

# In Powershell Prompt : conda install -c conda-forge multitasking
# pip install -i https://pypi.anaconda.org/ranaroussi/simple yfinance

import yfinance as yf

# To show all your output File -> Preferences -> Settings Search for Notebook
# Notebook Output Text Line Limit and set to 100

# Used for file handling like deleting files
import os

# conda install -c conda-forge cufflinks-py
# conda install -c plotly plotly
import cufflinks as cf
import plotly.express as px
import plotly.graph_objects as go

# Make Plotly work in your Jupyter Notebook
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)
# Use Plotly locally
cf.go_offline()

from plotly.subplots import make_subplots

# New Imports
# Used to get data from a directory
import os
from os import listdir
from os.path import isfile, join

import warnings
warnings.simplefilter("ignore")
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ## Constants

# %%
PATH = "C:/Users/jishm/CodingPractice/Invest/Wilshire_Stocks/"


# Start end date defaults
S_DATE = "2017-02-01"
E_DATE = "2022-12-06"
S_DATE_DT = pd.to_datetime(S_DATE)
E_DATE_DT = pd.to_datetime(E_DATE)

# %% [markdown]
# ## Get Column Data from CSV

# %%
def get_column_from_csv(file, col_name):
    # Try to get the file and if it doesn't exist issue a warning
    try:
        df = pd.read_csv(file)
    except FileNotFoundError:
        print("File Doesn't Exist")
    else:
        return df[col_name]

# %% [markdown]
# ## Get Stock Tickers

# %%
tickers = get_column_from_csv("C:/Users/jishm/CodingPractice/Invest/Wilshire-5000-Stocks.csv", "Ticker")
print(len(tickers))
# Out:
# 3481

# %% [markdown]
# ## Save Stock Data to CSV

# %%
# Function that gets a dataframe by providing a ticker and starting date
def save_to_csv_from_yahoo(folder, ticker):
    stock = yf.Ticker(ticker)
    
    try:
        print("Get Data for : ", ticker)
        # Get historical closing price data
        df = stock.history(period="5y")
    
        # Wait 2 seconds
        time.sleep(2)
        
        # Remove the period for saving the file name
        # Save data to a CSV file
        # File to save to 
        the_file = folder + ticker.replace(".", "_") + '.csv'
        print(the_file, " Saved")
        df.to_csv(the_file)
    except Exception as ex:
        print("Couldn't Get Data for :", ticker)

# %% [markdown]
# ## Download All Stocks

# %%
for x in range(0, 3481):
    save_to_csv_from_yahoo(PATH, tickers[x])
    print("Finished")
# Out:
# Get Data for :  A
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/A.csv  Saved
# Finished
# Get Data for :  AA
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AA.csv  Saved
# Finished
# Get Data for :  AAL
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AAL.csv  Saved
# Finished
# Get Data for :  AAME
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AAME.csv  Saved
# Finished
# Get Data for :  AAN
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AAN.csv  Saved
# Finished
# Get Data for :  AAOI
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AAOI.csv  Saved
# Finished
# Get Data for :  AAON
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AAON.csv  Saved
# Finished
# Get Data for :  AAP
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AAP.csv  Saved
# Finished
# Get Data for :  AAPL
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AAPL.csv  Saved
# Finished
# Get Data for :  AAT
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AAT.csv  Saved
# Finished
# Get Data for :  AAWW
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AAWW.csv  Saved
# Finished
# Get Data for :  AAXN
# - AAXN: No data found, symbol may be delisted
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AAXN.csv  Saved
# Finished
# Get Data for :  ABBV
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ABBV.csv  Saved
# Finished
# Get Data for :  ABC
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ABC.csv  Saved
# Finished
# Get Data for :  ABCB
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ABCB.csv  Saved
# Finished
# Get Data for :  ABEO
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ABEO.csv  Saved
# Finished
# Get Data for :  ABG
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ABG.csv  Saved
# Finished
# Get Data for :  ABIO
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ABIO.csv  Saved
# Finished
# Get Data for :  ABM
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ABM.csv  Saved
# Finished
# Get Data for :  ABMD
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ABMD.csv  Saved
# Finished
# Get Data for :  ABR
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ABR.csv  Saved
# Finished
# Get Data for :  ABT
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ABT.csv  Saved
# Finished
# Get Data for :  ABTX
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ABTX.csv  Saved
# Finished
# Get Data for :  AC
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AC.csv  Saved
# Finished
# Get Data for :  ACA
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ACA.csv  Saved
# Finished
# Get Data for :  ACAD
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ACAD.csv  Saved
# Finished
# Get Data for :  ACBI
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ACBI.csv  Saved
# Finished
# Get Data for :  ACC
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ACC.csv  Saved
# Finished
# Get Data for :  ACCO
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ACCO.csv  Saved
# Finished
# Get Data for :  ACER
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ACER.csv  Saved
# Finished
# Get Data for :  ACGL
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ACGL.csv  Saved
# Finished
# Get Data for :  ACHC
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ACHC.csv  Saved
# Finished
# Get Data for :  ACHV
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ACHV.csv  Saved
# Finished
# Get Data for :  ACIA
# - ACIA: No data found, symbol may be delisted
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ACIA.csv  Saved
# Finished
# Get Data for :  ACIW
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ACIW.csv  Saved
# Finished
# Get Data for :  ACLS
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ACLS.csv  Saved
# Finished
# Get Data for :  ACM
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ACM.csv  Saved
# Finished
# Get Data for :  ACMR
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ACMR.csv  Saved
# Finished
# Get Data for :  ACN
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ACN.csv  Saved
# Finished
# Get Data for :  ACNB
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ACNB.csv  Saved
# Finished
# Get Data for :  ACOR
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ACOR.csv  Saved
# Finished
# Get Data for :  ACRE
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ACRE.csv  Saved
# Finished
# Get Data for :  ACRS
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ACRS.csv  Saved
# Finished
# Get Data for :  ACRX
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ACRX.csv  Saved
# Finished
# Get Data for :  ACTG
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ACTG.csv  Saved
# Finished
# Get Data for :  ACU
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ACU.csv  Saved
# Finished
# Get Data for :  ACY
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ACY.csv  Saved
# Finished
# Get Data for :  ADBE
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ADBE.csv  Saved
# Finished
# Get Data for :  ADC
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ADC.csv  Saved
# Finished
# Get Data for :  ADES
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ADES.csv  Saved
# Finished
# Get Data for :  ADI
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ADI.csv  Saved
# Finished
# Get Data for :  ADM
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ADM.csv  Saved
# Finished
# Get Data for :  ADMA
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ADMA.csv  Saved
# Finished
# Get Data for :  ADMP
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ADMP.csv  Saved
# Finished
# Get Data for :  ADMS
# - ADMS: No data found, symbol may be delisted
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ADMS.csv  Saved
# Finished
# Get Data for :  ADNT
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ADNT.csv  Saved
# Finished
# Get Data for :  ADP
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ADP.csv  Saved
# Finished
# Get Data for :  ADRO
# - ADRO: No data found, symbol may be delisted
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ADRO.csv  Saved
# Finished
# Get Data for :  ADS
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ADS.csv  Saved
# Finished
# Get Data for :  ADSK
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ADSK.csv  Saved
# Finished
# Get Data for :  ADSW
# - ADSW: No data found, symbol may be delisted
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ADSW.csv  Saved
# Finished
# Get Data for :  ADT
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ADT.csv  Saved
# Finished
# Get Data for :  ADTN
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ADTN.csv  Saved
# Finished
# Get Data for :  ADUS
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ADUS.csv  Saved
# Finished
# Get Data for :  ADVM
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ADVM.csv  Saved
# Finished
# Get Data for :  ADXS
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ADXS.csv  Saved
# Finished
# Get Data for :  AE
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AE.csv  Saved
# Finished
# Get Data for :  AEE
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AEE.csv  Saved
# Finished
# Get Data for :  AEGN
# - AEGN: No data found, symbol may be delisted
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AEGN.csv  Saved
# Finished
# Get Data for :  AEHR
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AEHR.csv  Saved
# Finished
# Get Data for :  AEIS
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AEIS.csv  Saved
# Finished
# Get Data for :  AEL
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AEL.csv  Saved
# Finished
# Get Data for :  AEMD
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AEMD.csv  Saved
# Finished
# Get Data for :  AEO
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AEO.csv  Saved
# Finished
# Get Data for :  AEP
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AEP.csv  Saved
# Finished
# Get Data for :  AERI
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AERI.csv  Saved
# Finished
# Get Data for :  AES
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AES.csv  Saved
# Finished
# Get Data for :  AEY
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AEY.csv  Saved
# Finished
# Get Data for :  AFG
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AFG.csv  Saved
# Finished
# Get Data for :  AFH
# - AFH: No data found, symbol may be delisted
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AFH.csv  Saved
# Finished
# Get Data for :  AFI
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AFI.csv  Saved
# Finished
# Get Data for :  AFIN
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AFIN.csv  Saved
# Finished
# Get Data for :  AFL
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AFL.csv  Saved
# Finished
# Get Data for :  AGCO
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AGCO.csv  Saved
# Finished
# Get Data for :  AGE
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AGE.csv  Saved
# Finished
# Get Data for :  AGEN
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AGEN.csv  Saved
# Finished
# Get Data for :  AGFS
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AGFS.csv  Saved
# Finished
# Get Data for :  AGIO
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AGIO.csv  Saved
# Finished
# Get Data for :  AGLE
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AGLE.csv  Saved
# Finished
# Get Data for :  AGM
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AGM.csv  Saved
# Finished
# Get Data for :  AGNC
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AGNC.csv  Saved
# Finished
# Get Data for :  AGO
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AGO.csv  Saved
# Finished
# Get Data for :  AGR
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AGR.csv  Saved
# Finished
# Get Data for :  AGRX
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AGRX.csv  Saved
# Finished
# Get Data for :  AGS
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AGS.csv  Saved
# Finished
# Get Data for :  AGTC
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AGTC.csv  Saved
# Finished
# Get Data for :  AGX
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AGX.csv  Saved
# Finished
# Get Data for :  AGYS
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AGYS.csv  Saved
# Finished
# Get Data for :  AHC
# - AHC: No data found, symbol may be delisted
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AHC.csv  Saved
# Finished
# Get Data for :  AHH
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AHH.csv  Saved
# Finished
# Get Data for :  AHT
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AHT.csv  Saved
# Finished
# Get Data for :  AIG
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AIG.csv  Saved
# Finished
# Get Data for :  AIMC
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AIMC.csv  Saved
# Finished
# Get Data for :  AIMT
# - AIMT: No data found, symbol may be delisted
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AIMT.csv  Saved
# Finished
# Get Data for :  AIN
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AIN.csv  Saved
# Finished
# Get Data for :  AINC
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AINC.csv  Saved
# Finished
# Get Data for :  AIR
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AIR.csv  Saved
# Finished
# Get Data for :  AIRG
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AIRG.csv  Saved
# Finished
# Get Data for :  AIRI
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AIRI.csv  Saved
# Finished
# Get Data for :  AIRT
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AIRT.csv  Saved
# Finished
# Get Data for :  AIT
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AIT.csv  Saved
# Finished
# Get Data for :  AIV
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AIV.csv  Saved
# Finished
# Get Data for :  AIZ
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AIZ.csv  Saved
# Finished
# Get Data for :  AJG
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AJG.csv  Saved
# Finished
# Get Data for :  AJRD
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AJRD.csv  Saved
# Finished
# Get Data for :  AJX
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AJX.csv  Saved
# Finished
# Get Data for :  AKAM
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AKAM.csv  Saved
# Finished
# Get Data for :  AKBA
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AKBA.csv  Saved
# Finished
# Get Data for :  AKCA
# - AKCA: No data found, symbol may be delisted
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AKCA.csv  Saved
# Finished
# Get Data for :  AKER
# - AKER: No data found, symbol may be delisted
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AKER.csv  Saved
# Finished
# Get Data for :  AKR
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AKR.csv  Saved
# Finished
# Get Data for :  AKTS
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AKTS.csv  Saved
# Finished
# Get Data for :  AL
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AL.csv  Saved
# Finished
# Get Data for :  ALB
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ALB.csv  Saved
# Finished
# Get Data for :  ALBO
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ALBO.csv  Saved
# Finished
# Get Data for :  ALCO
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ALCO.csv  Saved
# Finished
# Get Data for :  ALDX
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ALDX.csv  Saved
# Finished
# Get Data for :  ALE
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ALE.csv  Saved
# Finished
# Get Data for :  ALEC
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ALEC.csv  Saved
# Finished
# Get Data for :  ALEX
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ALEX.csv  Saved
# Finished
# Get Data for :  ALG
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ALG.csv  Saved
# Finished
# Get Data for :  ALGN
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ALGN.csv  Saved
# Finished
# Get Data for :  ALGT
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ALGT.csv  Saved
# Finished
# Get Data for :  ALIM
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ALIM.csv  Saved
# Finished
# Get Data for :  ALJJ
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ALJJ.csv  Saved
# Finished
# Get Data for :  ALK
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ALK.csv  Saved
# Finished
# Get Data for :  ALKS
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ALKS.csv  Saved
# Finished
# Get Data for :  ALL
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ALL.csv  Saved
# Finished
# Get Data for :  ALLE
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ALLE.csv  Saved
# Finished
# Get Data for :  ALLK
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ALLK.csv  Saved
# Finished
# Get Data for :  ALLO
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ALLO.csv  Saved
# Finished
# Get Data for :  ALLY
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ALLY.csv  Saved
# Finished
# Get Data for :  ALNA
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ALNA.csv  Saved
# Finished
# Get Data for :  ALNY
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ALNY.csv  Saved
# Finished
# Get Data for :  ALOT
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ALOT.csv  Saved
# Finished
# Get Data for :  ALPN
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ALPN.csv  Saved
# Finished
# Get Data for :  ALRM
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ALRM.csv  Saved
# Finished
# Get Data for :  ALSK
# - ALSK: No data found, symbol may be delisted
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ALSK.csv  Saved
# Finished
# Get Data for :  ALSN
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ALSN.csv  Saved
# Finished
# Get Data for :  ALT
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ALT.csv  Saved
# Finished
# Get Data for :  ALTM
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ALTM.csv  Saved
# Finished
# Get Data for :  ALTR
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ALTR.csv  Saved
# Finished
# Get Data for :  ALV
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ALV.csv  Saved
# Finished
# Get Data for :  ALX
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ALX.csv  Saved
# Finished
# Get Data for :  ALXN
# - ALXN: No data found, symbol may be delisted
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ALXN.csv  Saved
# Finished
# Get Data for :  AM
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AM.csv  Saved
# Finished
# Get Data for :  AMAG
# - AMAG: No data found, symbol may be delisted
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AMAG.csv  Saved
# Finished
# Get Data for :  AMAL
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AMAL.csv  Saved
# Finished
# Get Data for :  AMAT
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AMAT.csv  Saved
# Finished
# Get Data for :  AMBC
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AMBC.csv  Saved
# Finished
# Get Data for :  AMC
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AMC.csv  Saved
# Finished
# Get Data for :  AMCX
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AMCX.csv  Saved
# Finished
# Get Data for :  AMD
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AMD.csv  Saved
# Finished
# Get Data for :  AME
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AME.csv  Saved
# Finished
# Get Data for :  AMED
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AMED.csv  Saved
# Finished
# Get Data for :  AMG
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AMG.csv  Saved
# Finished
# Get Data for :  AMGN
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AMGN.csv  Saved
# Finished
# Get Data for :  AMH
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AMH.csv  Saved
# Finished
# Get Data for :  AMKR
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AMKR.csv  Saved
# Finished
# Get Data for :  AMN
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AMN.csv  Saved
# Finished
# Get Data for :  AMNB
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AMNB.csv  Saved
# Finished
# Get Data for :  AMOT
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AMOT.csv  Saved
# Finished
# Get Data for :  AMP
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AMP.csv  Saved
# Finished
# Get Data for :  AMPE
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AMPE.csv  Saved
# Finished
# Get Data for :  AMPH
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AMPH.csv  Saved
# Finished
# Get Data for :  AMRB
# - AMRB: No data found, symbol may be delisted
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AMRB.csv  Saved
# Finished
# Get Data for :  AMRC
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AMRC.csv  Saved
# Finished
# Get Data for :  AMRK
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AMRK.csv  Saved
# Finished
# Get Data for :  AMRS
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AMRS.csv  Saved
# Finished
# Get Data for :  AMRX
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AMRX.csv  Saved
# Finished
# Get Data for :  AMS
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AMS.csv  Saved
# Finished
# Get Data for :  AMSC
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AMSC.csv  Saved
# Finished
# Get Data for :  AMSF
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AMSF.csv  Saved
# Finished
# Get Data for :  AMSWA
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AMSWA.csv  Saved
# Finished
# Get Data for :  AMT
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AMT.csv  Saved
# Finished
# Get Data for :  AMTD
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AMTD.csv  Saved
# Finished
# Get Data for :  AMTX
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AMTX.csv  Saved
# Finished
# Get Data for :  AMWD
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AMWD.csv  Saved
# Finished
# Get Data for :  AMZN
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AMZN.csv  Saved
# Finished
# Get Data for :  AN
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AN.csv  Saved
# Finished
# Get Data for :  ANAB
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ANAB.csv  Saved
# Finished
# Get Data for :  ANAT
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ANAT.csv  Saved
# Finished
# Get Data for :  ANDE
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ANDE.csv  Saved
# Finished
# Get Data for :  ANET
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ANET.csv  Saved
# Finished
# Get Data for :  ANF
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ANF.csv  Saved
# Finished
# Get Data for :  ANGI
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ANGI.csv  Saved
# Finished
# Get Data for :  ANGO
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ANGO.csv  Saved
# Finished
# Get Data for :  ANH
# - ANH: No data found, symbol may be delisted
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ANH.csv  Saved
# Finished
# Get Data for :  ANIK
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ANIK.csv  Saved
# Finished
# Get Data for :  ANIP
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ANIP.csv  Saved
# Finished
# Get Data for :  ANIX
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ANIX.csv  Saved
# Finished
# Get Data for :  ANSS
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ANSS.csv  Saved
# Finished
# Get Data for :  ANTM
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ANTM.csv  Saved
# Finished
# Get Data for :  AON
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AON.csv  Saved
# Finished
# Get Data for :  AOS
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AOS.csv  Saved
# Finished
# Get Data for :  AOSL
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AOSL.csv  Saved
# Finished
# Get Data for :  AP
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AP.csv  Saved
# Finished
# Get Data for :  APA
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/APA.csv  Saved
# Finished
# Get Data for :  APAM
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/APAM.csv  Saved
# Finished
# Get Data for :  APD
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/APD.csv  Saved
# Finished
# Get Data for :  APDN
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/APDN.csv  Saved
# Finished
# Get Data for :  APEI
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/APEI.csv  Saved
# Finished
# Get Data for :  APEN
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/APEN.csv  Saved
# Finished
# Get Data for :  APH
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/APH.csv  Saved
# Finished
# Get Data for :  APLE
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/APLE.csv  Saved
# Finished
# Get Data for :  APLS
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/APLS.csv  Saved
# Finished
# Get Data for :  APOG
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/APOG.csv  Saved
# Finished
# Get Data for :  APPF
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/APPF.csv  Saved
# Finished
# Get Data for :  APPN
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/APPN.csv  Saved
# Finished
# Get Data for :  APPS
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/APPS.csv  Saved
# Finished
# Get Data for :  APRN
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/APRN.csv  Saved
# Finished
# Get Data for :  APT
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/APT.csv  Saved
# Finished
# Get Data for :  APTS
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/APTS.csv  Saved
# Finished
# Get Data for :  APTV
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/APTV.csv  Saved
# Finished
# Get Data for :  APVO
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/APVO.csv  Saved
# Finished
# Get Data for :  APYX
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/APYX.csv  Saved
# Finished
# Get Data for :  AQB
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AQB.csv  Saved
# Finished
# Get Data for :  AQMS
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AQMS.csv  Saved
# Finished
# Get Data for :  AQUA
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AQUA.csv  Saved
# Finished
# Get Data for :  AR
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AR.csv  Saved
# Finished
# Get Data for :  ARA
# - ARA: No data found, symbol may be delisted
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ARA.csv  Saved
# Finished
# Get Data for :  ARAV
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ARAV.csv  Saved
# Finished
# Get Data for :  ARAY
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ARAY.csv  Saved
# Finished
# Get Data for :  ARC
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ARC.csv  Saved
# Finished
# Get Data for :  ARCB
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ARCB.csv  Saved
# Finished
# Get Data for :  ARCH
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ARCH.csv  Saved
# Finished
# Get Data for :  ARDX
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ARDX.csv  Saved
# Finished
# Get Data for :  ARE
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ARE.csv  Saved
# Finished
# Get Data for :  ARES
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ARES.csv  Saved
# Finished
# Get Data for :  ARGO
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ARGO.csv  Saved
# Finished
# Get Data for :  ARI
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ARI.csv  Saved
# Finished
# Get Data for :  ARKR
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ARKR.csv  Saved
# Finished
# Get Data for :  ARL
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ARL.csv  Saved
# Finished
# Get Data for :  ARLO
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ARLO.csv  Saved
# Finished
# Get Data for :  ARMK
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ARMK.csv  Saved
# Finished
# Get Data for :  ARNA
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ARNA.csv  Saved
# Finished
# Get Data for :  ARNC
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ARNC.csv  Saved
# Finished
# Get Data for :  AROC
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AROC.csv  Saved
# Finished
# Get Data for :  AROW
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AROW.csv  Saved
# Finished
# Get Data for :  ARPO
# - ARPO: No data found, symbol may be delisted
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ARPO.csv  Saved
# Finished
# Get Data for :  ARR
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ARR.csv  Saved
# Finished
# Get Data for :  ARTNA
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ARTNA.csv  Saved
# Finished
# Get Data for :  ARTW
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ARTW.csv  Saved
# Finished
# Get Data for :  ARVN
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ARVN.csv  Saved
# Finished
# Get Data for :  ARW
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ARW.csv  Saved
# Finished
# Get Data for :  ARWR
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ARWR.csv  Saved
# Finished
# Get Data for :  ASB
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ASB.csv  Saved
# Finished
# Get Data for :  ASFI
# - ASFI: No data found, symbol may be delisted
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ASFI.csv  Saved
# Finished
# Get Data for :  ASGN
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ASGN.csv  Saved
# Finished
# Get Data for :  ASH
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ASH.csv  Saved
# Finished
# Get Data for :  ASIX
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ASIX.csv  Saved
# Finished
# Get Data for :  ASMB
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ASMB.csv  Saved
# Finished
# Get Data for :  ASNA
# - ASNA: No data found, symbol may be delisted
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ASNA.csv  Saved
# Finished
# Get Data for :  ASPN
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ASPN.csv  Saved
# Finished
# Get Data for :  ASPS
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ASPS.csv  Saved
# Finished
# Get Data for :  ASRT
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ASRT.csv  Saved
# Finished
# Get Data for :  ASRV
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ASRV.csv  Saved
# Finished
# Get Data for :  ASTC
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ASTC.csv  Saved
# Finished
# Get Data for :  ASTE
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ASTE.csv  Saved
# Finished
# Get Data for :  ASUR
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ASUR.csv  Saved
# Finished
# Get Data for :  ASYS
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ASYS.csv  Saved
# Finished
# Get Data for :  ATEC
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ATEC.csv  Saved
# Finished
# Get Data for :  ATEN
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ATEN.csv  Saved
# Finished
# Get Data for :  ATGE
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ATGE.csv  Saved
# Finished
# Get Data for :  ATH
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ATH.csv  Saved
# Finished
# Get Data for :  ATHX
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ATHX.csv  Saved
# Finished
# Get Data for :  ATI
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ATI.csv  Saved
# Finished
# Get Data for :  ATKR
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ATKR.csv  Saved
# Finished
# Get Data for :  ATLC
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ATLC.csv  Saved
# Finished
# Get Data for :  ATLO
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ATLO.csv  Saved
# Finished
# Get Data for :  ATNI
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ATNI.csv  Saved
# Finished
# Get Data for :  ATNM
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ATNM.csv  Saved
# Finished
# Get Data for :  ATNX
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ATNX.csv  Saved
# Finished
# Get Data for :  ATO
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ATO.csv  Saved
# Finished
# Get Data for :  ATOS
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ATOS.csv  Saved
# Finished
# Get Data for :  ATR
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ATR.csv  Saved
# Finished
# Get Data for :  ATRA
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ATRA.csv  Saved
# Finished
# Get Data for :  ATRC
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ATRC.csv  Saved
# Finished
# Get Data for :  ATRI
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ATRI.csv  Saved
# Finished
# Get Data for :  ATRO
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ATRO.csv  Saved
# Finished
# Get Data for :  ATRS
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ATRS.csv  Saved
# Finished
# Get Data for :  ATSG
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ATSG.csv  Saved
# Finished
# Get Data for :  ATUS
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ATUS.csv  Saved
# Finished
# Get Data for :  ATVI
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ATVI.csv  Saved
# Finished
# Get Data for :  AUBN
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AUBN.csv  Saved
# Finished
# Get Data for :  AUMN
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AUMN.csv  Saved
# Finished
# Get Data for :  AUTO
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AUTO.csv  Saved
# Finished
# Get Data for :  AVA
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AVA.csv  Saved
# Finished
# Get Data for :  AVAV
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AVAV.csv  Saved
# Finished
# Get Data for :  AVB
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AVB.csv  Saved
# Finished
# Get Data for :  AVD
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AVD.csv  Saved
# Finished
# Get Data for :  AVEO
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AVEO.csv  Saved
# Finished
# Get Data for :  AVGO
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AVGO.csv  Saved
# Finished
# Get Data for :  AVGR
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AVGR.csv  Saved
# Finished
# Get Data for :  AVID
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AVID.csv  Saved
# Finished
# Get Data for :  AVLR
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AVLR.csv  Saved
# Finished
# Get Data for :  AVNS
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AVNS.csv  Saved
# Finished
# Get Data for :  AVNW
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AVNW.csv  Saved
# Finished
# Get Data for :  AVRO
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AVRO.csv  Saved
# Finished
# Get Data for :  AVT
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AVT.csv  Saved
# Finished
# Get Data for :  AVTR
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AVTR.csv  Saved
# Finished
# Get Data for :  AVXL
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AVXL.csv  Saved
# Finished
# Get Data for :  AVY
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AVY.csv  Saved
# Finished
# Get Data for :  AVYA
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AVYA.csv  Saved
# Finished
# Get Data for :  AWI
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AWI.csv  Saved
# Finished
# Get Data for :  AWK
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AWK.csv  Saved
# Finished
# Get Data for :  AWR
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AWR.csv  Saved
# Finished
# Get Data for :  AWRE
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AWRE.csv  Saved
# Finished
# Get Data for :  AWSM
# - AWSM: No data found, symbol may be delisted
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AWSM.csv  Saved
# Finished
# Get Data for :  AX
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AX.csv  Saved
# Finished
# Get Data for :  AXAS
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AXAS.csv  Saved
# Finished
# Get Data for :  AXDX
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AXDX.csv  Saved
# Finished
# Get Data for :  AXE
# - AXE: No data found, symbol may be delisted
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AXE.csv  Saved
# Finished
# Get Data for :  AXGN
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AXGN.csv  Saved
# Finished
# Get Data for :  AXL
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AXL.csv  Saved
# Finished
# Get Data for :  AXNX
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AXNX.csv  Saved
# Finished
# Get Data for :  AXP
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AXP.csv  Saved
# Finished
# Get Data for :  AXR
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AXR.csv  Saved
# Finished
# Get Data for :  AXS
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AXS.csv  Saved
# Finished
# Get Data for :  AXSM
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AXSM.csv  Saved
# Finished
# Get Data for :  AXTA
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AXTA.csv  Saved
# Finished
# Get Data for :  AXTI
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AXTI.csv  Saved
# Finished
# Get Data for :  AYI
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AYI.csv  Saved
# Finished
# Get Data for :  AYX
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AYX.csv  Saved
# Finished
# Get Data for :  AZO
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AZO.csv  Saved
# Finished
# Get Data for :  AZPN
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AZPN.csv  Saved
# Finished
# Get Data for :  AZZ
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/AZZ.csv  Saved
# Finished
# Get Data for :  B
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/B.csv  Saved
# Finished
# Get Data for :  BA
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BA.csv  Saved
# Finished
# Get Data for :  BAC
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BAC.csv  Saved
# Finished
# Get Data for :  BAH
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BAH.csv  Saved
# Finished
# Get Data for :  BANC
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BANC.csv  Saved
# Finished
# Get Data for :  BAND
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BAND.csv  Saved
# Finished
# Get Data for :  BANF
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BANF.csv  Saved
# Finished
# Get Data for :  BANR
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BANR.csv  Saved
# Finished
# Get Data for :  BASI
# - BASI: No data found, symbol may be delisted
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BASI.csv  Saved
# Finished
# Get Data for :  BATRA
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BATRA.csv  Saved
# Finished
# Get Data for :  BATRK
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BATRK.csv  Saved
# Finished
# Get Data for :  BAX
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BAX.csv  Saved
# Finished
# Get Data for :  BBBY
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BBBY.csv  Saved
# Finished
# Get Data for :  BBCP
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BBCP.csv  Saved
# Finished
# Get Data for :  BBGI
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BBGI.csv  Saved
# Finished
# Get Data for :  BBSI
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BBSI.csv  Saved
# Finished
# Get Data for :  BBW
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BBW.csv  Saved
# Finished
# Get Data for :  BBY
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BBY.csv  Saved
# Finished
# Get Data for :  BC
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BC.csv  Saved
# Finished
# Get Data for :  BCBP
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BCBP.csv  Saved
# Finished
# Get Data for :  BCC
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BCC.csv  Saved
# Finished
# Get Data for :  BCEI
# - BCEI: No data found, symbol may be delisted
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BCEI.csv  Saved
# Finished
# Get Data for :  BCLI
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BCLI.csv  Saved
# Finished
# Get Data for :  BCO
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BCO.csv  Saved
# Finished
# Get Data for :  BCOR
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BCOR.csv  Saved
# Finished
# Get Data for :  BCOV
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BCOV.csv  Saved
# Finished
# Get Data for :  BCPC
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BCPC.csv  Saved
# Finished
# Get Data for :  BCRX
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BCRX.csv  Saved
# Finished
# Get Data for :  BDC
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BDC.csv  Saved
# Finished
# Get Data for :  BDGE
# - BDGE: No data found, symbol may be delisted
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BDGE.csv  Saved
# Finished
# Get Data for :  BDL
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BDL.csv  Saved
# Finished
# Get Data for :  BDN
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BDN.csv  Saved
# Finished
# Get Data for :  BDSI
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BDSI.csv  Saved
# Finished
# Get Data for :  BDX
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BDX.csv  Saved
# Finished
# Get Data for :  BE
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BE.csv  Saved
# Finished
# Get Data for :  BEAT
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BEAT.csv  Saved
# Finished
# Get Data for :  BECN
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BECN.csv  Saved
# Finished
# Get Data for :  BELFA
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BELFA.csv  Saved
# Finished
# Get Data for :  BELFB
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BELFB.csv  Saved
# Finished
# Get Data for :  BEN
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BEN.csv  Saved
# Finished
# Get Data for :  BERY
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BERY.csv  Saved
# Finished
# Get Data for :  BFAM
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BFAM.csv  Saved
# Finished
# Get Data for :  BFIN
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BFIN.csv  Saved
# Finished
# Get Data for :  BFS
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BFS.csv  Saved
# Finished
# Get Data for :  BFST
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BFST.csv  Saved
# Finished
# Get Data for :  BG
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BG.csv  Saved
# Finished
# Get Data for :  BGCP
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BGCP.csv  Saved
# Finished
# Get Data for :  BGFV
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BGFV.csv  Saved
# Finished
# Get Data for :  BGS
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BGS.csv  Saved
# Finished
# Get Data for :  BGSF
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BGSF.csv  Saved
# Finished
# Get Data for :  BH
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BH.csv  Saved
# Finished
# Get Data for :  BHB
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BHB.csv  Saved
# Finished
# Get Data for :  BHE
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BHE.csv  Saved
# Finished
# Get Data for :  BHF
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BHF.csv  Saved
# Finished
# Get Data for :  BHLB
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BHLB.csv  Saved
# Finished
# Get Data for :  BHR
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BHR.csv  Saved
# Finished
# Get Data for :  BHVN
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BHVN.csv  Saved
# Finished
# Get Data for :  BIG
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BIG.csv  Saved
# Finished
# Get Data for :  BIIB
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BIIB.csv  Saved
# Finished
# Get Data for :  BIO
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BIO.csv  Saved
# Finished
# Get Data for :  BIOC
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BIOC.csv  Saved
# Finished
# Get Data for :  BIOL
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BIOL.csv  Saved
# Finished
# Get Data for :  BJ
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BJ.csv  Saved
# Finished
# Get Data for :  BJRI
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BJRI.csv  Saved
# Finished
# Get Data for :  BK
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BK.csv  Saved
# Finished
# Get Data for :  BKD
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BKD.csv  Saved
# Finished
# Get Data for :  BKE
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BKE.csv  Saved
# Finished
# Get Data for :  BKH
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BKH.csv  Saved
# Finished
# Get Data for :  BKI
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BKI.csv  Saved
# Finished
# Get Data for :  BKNG
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BKNG.csv  Saved
# Finished
# Get Data for :  BKSC
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BKSC.csv  Saved
# Finished
# Get Data for :  BKTI
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BKTI.csv  Saved
# Finished
# Get Data for :  BKU
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BKU.csv  Saved
# Finished
# Get Data for :  BL
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BL.csv  Saved
# Finished
# Get Data for :  BLBD
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BLBD.csv  Saved
# Finished
# Get Data for :  BLCM
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BLCM.csv  Saved
# Finished
# Get Data for :  BLD
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BLD.csv  Saved
# Finished
# Get Data for :  BLDR
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BLDR.csv  Saved
# Finished
# Get Data for :  BLFS
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BLFS.csv  Saved
# Finished
# Get Data for :  BLK
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BLK.csv  Saved
# Finished
# Get Data for :  BLKB
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BLKB.csv  Saved
# Finished
# Get Data for :  BLL
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BLL.csv  Saved
# Finished
# Get Data for :  BLMN
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BLMN.csv  Saved
# Finished
# Get Data for :  BLUE
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BLUE.csv  Saved
# Finished
# Get Data for :  BMCH
# - BMCH: No data found, symbol may be delisted
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BMCH.csv  Saved
# Finished
# Get Data for :  BMI
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BMI.csv  Saved
# Finished
# Get Data for :  BMRC
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BMRC.csv  Saved
# Finished
# Get Data for :  BMRN
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BMRN.csv  Saved
# Finished
# Get Data for :  BMTC
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BMTC.csv  Saved
# Finished
# Get Data for :  BMY
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BMY.csv  Saved
# Finished
# Get Data for :  BNED
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BNED.csv  Saved
# Finished
# Get Data for :  BNFT
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BNFT.csv  Saved
# Finished
# Get Data for :  BOCH
# - BOCH: No data found, symbol may be delisted
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BOCH.csv  Saved
# Finished
# Get Data for :  BOH
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BOH.csv  Saved
# Finished
# Get Data for :  BOKF
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BOKF.csv  Saved
# Finished
# Get Data for :  BOMN
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BOMN.csv  Saved
# Finished
# Get Data for :  BOOM
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BOOM.csv  Saved
# Finished
# Get Data for :  BOOT
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BOOT.csv  Saved
# Finished
# Get Data for :  BOTJ
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BOTJ.csv  Saved
# Finished
# Get Data for :  BOX
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BOX.csv  Saved
# Finished
# Get Data for :  BPFH
# - BPFH: No data found, symbol may be delisted
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BPFH.csv  Saved
# Finished
# Get Data for :  BPMC
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BPMC.csv  Saved
# Finished
# Get Data for :  BPOP
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BPOP.csv  Saved
# Finished
# Get Data for :  BPRN
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BPRN.csv  Saved
# Finished
# Get Data for :  BPTH
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BPTH.csv  Saved
# Finished
# Get Data for :  BR
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BR.csv  Saved
# Finished
# Get Data for :  BRC
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BRC.csv  Saved
# Finished
# Get Data for :  BREW
# - BREW: No data found, symbol may be delisted
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BREW.csv  Saved
# Finished
# Get Data for :  BRG
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BRG.csv  Saved
# Finished
# Get Data for :  BRID
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BRID.csv  Saved
# Finished
# Get Data for :  BRKL
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BRKL.csv  Saved
# Finished
# Get Data for :  BRKR
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BRKR.csv  Saved
# Finished
# Get Data for :  BRKS
# - BRKS: No data found, symbol may be delisted
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BRKS.csv  Saved
# Finished
# Get Data for :  BRN
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BRN.csv  Saved
# Finished
# Get Data for :  BRO
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BRO.csv  Saved
# Finished
# Get Data for :  BRT
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BRT.csv  Saved
# Finished
# Get Data for :  BRX
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BRX.csv  Saved
# Finished
# Get Data for :  BRY
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BRY.csv  Saved
# Finished
# Get Data for :  BSET
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BSET.csv  Saved
# Finished
# Get Data for :  BSGM
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BSGM.csv  Saved
# Finished
# Get Data for :  BSQR
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BSQR.csv  Saved
# Finished
# Get Data for :  BSRR
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BSRR.csv  Saved
# Finished
# Get Data for :  BSTC
# - BSTC: No data found, symbol may be delisted
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BSTC.csv  Saved
# Finished
# Get Data for :  BSX
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BSX.csv  Saved
# Finished
# Get Data for :  BTN
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BTN.csv  Saved
# Finished
# Get Data for :  BTU
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BTU.csv  Saved
# Finished
# Get Data for :  BURL
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BURL.csv  Saved
# Finished
# Get Data for :  BUSE
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BUSE.csv  Saved
# Finished
# Get Data for :  BV
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BV.csv  Saved
# Finished
# Get Data for :  BW
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BW.csv  Saved
# Finished
# Get Data for :  BWA
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BWA.csv  Saved
# Finished
# Get Data for :  BWEN
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BWEN.csv  Saved
# Finished
# Get Data for :  BWFG
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BWFG.csv  Saved
# Finished
# Get Data for :  BWXT
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BWXT.csv  Saved
# Finished
# Get Data for :  BXC
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BXC.csv  Saved
# Finished
# Get Data for :  BXMT
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BXMT.csv  Saved
# Finished
# Get Data for :  BXP
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/BXP.csv  Saved
# Finished
# Get Data for :  BXS
# ...
# Finished
# Get Data for :  VNRX
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/VNRX.csv  Saved
# Finished
# Get Data for :  VISI
# - VISI: No data found, symbol may be delisted
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/VISI.csv  Saved
# Finished
# Get Data for :  VG
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/VG.csv  Saved
# Finished
# Get Data for :  VNO
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/VNO.csv  Saved
# Finished
# Get Data for :  VOXX
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/VOXX.csv  Saved
# Finished
# Get Data for :  VOYA
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/VOYA.csv  Saved
# Finished
# Get Data for :  VYGR
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/VYGR.csv  Saved
# Finished
# Get Data for :  VSEC
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/VSEC.csv  Saved
# Finished
# Get Data for :  VTVT
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/VTVT.csv  Saved
# Finished
# Get Data for :  VMC
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/VMC.csv  Saved
# Finished
# Get Data for :  VUZI
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/VUZI.csv  Saved
# Finished
# Get Data for :  WTI
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/WTI.csv  Saved
# Finished
# Get Data for :  WPC
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/WPC.csv  Saved
# Finished
# Get Data for :  WRB
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/WRB.csv  Saved
# Finished
# Get Data for :  GRA
# - GRA: No data found, symbol may be delisted
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/GRA.csv  Saved
# Finished
# Get Data for :  GWW
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/GWW.csv  Saved
# Finished
# Get Data for :  WNC
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/WNC.csv  Saved
# Finished
# Get Data for :  WBC
# - WBC: No data found, symbol may be delisted
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/WBC.csv  Saved
# Finished
# Get Data for :  WDR
# - WDR: No data found, symbol may be delisted
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/WDR.csv  Saved
# Finished
# Get Data for :  WTRH
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/WTRH.csv  Saved
# Finished
# Get Data for :  WBA
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/WBA.csv  Saved
# Finished
# Get Data for :  WD
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/WD.csv  Saved
# Finished
# Get Data for :  WMT
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/WMT.csv  Saved
# Finished
# Get Data for :  HCC
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/HCC.csv  Saved
# Finished
# Get Data for :  WAFD
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/WAFD.csv  Saved
# Finished
# Get Data for :  WPG
# - WPG: No data found, symbol may be delisted
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/WPG.csv  Saved
# Finished
# Get Data for :  WRE
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/WRE.csv  Saved
# Finished
# Get Data for :  WASH
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/WASH.csv  Saved
# Finished
# Get Data for :  WM
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/WM.csv  Saved
# Finished
# Get Data for :  WAT
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/WAT.csv  Saved
# Finished
# Get Data for :  WSBF
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/WSBF.csv  Saved
# Finished
# Get Data for :  WSO
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/WSO.csv  Saved
# Finished
# Get Data for :  WTS
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/WTS.csv  Saved
# Finished
# Get Data for :  WVE
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/WVE.csv  Saved
# Finished
# Get Data for :  W
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/W.csv  Saved
# Finished
# Get Data for :  WSTG
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/WSTG.csv  Saved
# Finished
# Get Data for :  WDFC
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/WDFC.csv  Saved
# Finished
# Get Data for :  WBS
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/WBS.csv  Saved
# Finished
# Get Data for :  WEC
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/WEC.csv  Saved
# Finished
# Get Data for :  WRI
# - WRI: No data found, symbol may be delisted
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/WRI.csv  Saved
# Finished
# Get Data for :  WMK
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/WMK.csv  Saved
# Finished
# Get Data for :  WBT
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/WBT.csv  Saved
# Finished
# Get Data for :  WCG
# - WCG: No data found, symbol may be delisted
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/WCG.csv  Saved
# Finished
# Get Data for :  WEBK
# - WEBK: No data found, symbol may be delisted
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/WEBK.csv  Saved
# Finished
# Get Data for :  WFC
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/WFC.csv  Saved
# Finished
# Get Data for :  WELL
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/WELL.csv  Saved
# Finished
# Get Data for :  WERN
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/WERN.csv  Saved
# Finished
# Get Data for :  WSBC
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/WSBC.csv  Saved
# Finished
# Get Data for :  WAIR
# - WAIR: No data found, symbol may be delisted
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/WAIR.csv  Saved
# Finished
# Get Data for :  WCC
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/WCC.csv  Saved
# Finished
# Get Data for :  WTBA
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/WTBA.csv  Saved
# Finished
# Get Data for :  WST
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/WST.csv  Saved
# Finished
# Get Data for :  WABC
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/WABC.csv  Saved
# Finished
# Get Data for :  WSTL
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/WSTL.csv  Saved
# Finished
# Get Data for :  WAL
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/WAL.csv  Saved
# Finished
# Get Data for :  WMC
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/WMC.csv  Saved
# Finished
# Get Data for :  WDC
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/WDC.csv  Saved
# Finished
# Get Data for :  WNEB
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/WNEB.csv  Saved
# Finished
# Get Data for :  WAB
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/WAB.csv  Saved
# Finished
# Get Data for :  WLK
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/WLK.csv  Saved
# Finished
# Get Data for :  WRK
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/WRK.csv  Saved
# Finished
# Get Data for :  WWR
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/WWR.csv  Saved
# Finished
# Get Data for :  WHG
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/WHG.csv  Saved
# Finished
# Get Data for :  WEX
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/WEX.csv  Saved
# Finished
# Get Data for :  WEYS
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/WEYS.csv  Saved
# Finished
# Get Data for :  WY
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/WY.csv  Saved
# Finished
# Get Data for :  WHLR
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/WHLR.csv  Saved
# Finished
# Get Data for :  WHR
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/WHR.csv  Saved
# Finished
# Get Data for :  WTM
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/WTM.csv  Saved
# Finished
# Get Data for :  WSR
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/WSR.csv  Saved
# Finished
# Get Data for :  WLL
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/WLL.csv  Saved
# Finished
# Get Data for :  WOW
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/WOW.csv  Saved
# Finished
# Get Data for :  WYY
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/WYY.csv  Saved
# Finished
# Get Data for :  WHLM
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/WHLM.csv  Saved
# Finished
# Get Data for :  WVVI
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/WVVI.csv  Saved
# Finished
# Get Data for :  WLDN
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/WLDN.csv  Saved
# Finished
# Get Data for :  WLH
# - WLH: No data found, symbol may be delisted
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/WLH.csv  Saved
# Finished
# Get Data for :  WSM
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/WSM.csv  Saved
# Finished
# Get Data for :  WLFC
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/WLFC.csv  Saved
# Finished
# Get Data for :  WLTW
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/WLTW.csv  Saved
# Finished
# Get Data for :  WSC
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/WSC.csv  Saved
# Finished
# Get Data for :  WING
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/WING.csv  Saved
# Finished
# Get Data for :  WINA
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/WINA.csv  Saved
# Finished
# Get Data for :  WGO
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/WGO.csv  Saved
# Finished
# Get Data for :  WTFC
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/WTFC.csv  Saved
# Finished
# Get Data for :  WTT
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/WTT.csv  Saved
# Finished
# Get Data for :  WETF
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/WETF.csv  Saved
# Finished
# Get Data for :  WWW
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/WWW.csv  Saved
# Finished
# Get Data for :  WWD
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/WWD.csv  Saved
# Finished
# Get Data for :  WDAY
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/WDAY.csv  Saved
# Finished
# Get Data for :  WKHS
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/WKHS.csv  Saved
# Finished
# Get Data for :  WK
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/WK.csv  Saved
# Finished
# Get Data for :  WRLD
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/WRLD.csv  Saved
# Finished
# Get Data for :  INT
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/INT.csv  Saved
# Finished
# Get Data for :  WWE
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/WWE.csv  Saved
# Finished
# Get Data for :  WOR
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/WOR.csv  Saved
# Finished
# Get Data for :  WPX
# - WPX: No data found, symbol may be delisted
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/WPX.csv  Saved
# Finished
# Get Data for :  WRTC
# - WRTC: No data found, symbol may be delisted
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/WRTC.csv  Saved
# Finished
# Get Data for :  WMGI
# - WMGI: No data found, symbol may be delisted
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/WMGI.csv  Saved
# Finished
# Get Data for :  WSFS
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/WSFS.csv  Saved
# Finished
# Get Data for :  WVFC
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/WVFC.csv  Saved
# Finished
# Get Data for :  WW
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/WW.csv  Saved
# Finished
# Get Data for :  WYND
# - WYND: No data found, symbol may be delisted
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/WYND.csv  Saved
# Finished
# Get Data for :  WH
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/WH.csv  Saved
# Finished
# Get Data for :  WYNN
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/WYNN.csv  Saved
# Finished
# Get Data for :  XFOR
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/XFOR.csv  Saved
# Finished
# Get Data for :  XBIT
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/XBIT.csv  Saved
# Finished
# Get Data for :  XELB
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/XELB.csv  Saved
# Finished
# Get Data for :  XEL
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/XEL.csv  Saved
# Finished
# Get Data for :  XNCR
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/XNCR.csv  Saved
# Finished
# Get Data for :  XHR
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/XHR.csv  Saved
# Finished
# Get Data for :  XERS
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/XERS.csv  Saved
# Finished
# Get Data for :  XRX
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/XRX.csv  Saved
# Finished
# Get Data for :  XLNX
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/XLNX.csv  Saved
# Finished
# Get Data for :  XOMA
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/XOMA.csv  Saved
# Finished
# Get Data for :  XPER
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/XPER.csv  Saved
# Finished
# Get Data for :  XPO
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/XPO.csv  Saved
# Finished
# Get Data for :  XSPA
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/XSPA.csv  Saved
# Finished
# Get Data for :  XTNT
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/XTNT.csv  Saved
# Finished
# Get Data for :  XYL
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/XYL.csv  Saved
# Finished
# Get Data for :  YELP
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/YELP.csv  Saved
# Finished
# Get Data for :  YETI
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/YETI.csv  Saved
# Finished
# Get Data for :  YEXT
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/YEXT.csv  Saved
# Finished
# Get Data for :  YTEN
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/YTEN.csv  Saved
# Finished
# Get Data for :  YMAB
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/YMAB.csv  Saved
# Finished
# Get Data for :  YORW
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/YORW.csv  Saved
# Finished
# Get Data for :  YRCW
# - YRCW: No data found, symbol may be delisted
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/YRCW.csv  Saved
# Finished
# Get Data for :  YUM
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/YUM.csv  Saved
# Finished
# Get Data for :  YUMA
# - YUMA: No data found, symbol may be delisted
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/YUMA.csv  Saved
# Finished
# Get Data for :  CTIB
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/CTIB.csv  Saved
# Finished
# Get Data for :  ZFGN
# - ZFGN: No data found, symbol may be delisted
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ZFGN.csv  Saved
# Finished
# Get Data for :  ZAGG
# - ZAGG: No data found, symbol may be delisted
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ZAGG.csv  Saved
# Finished
# Get Data for :  ZAYO
# - ZAYO: No data found, symbol may be delisted
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ZAYO.csv  Saved
# Finished
# Get Data for :  ZBRA
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ZBRA.csv  Saved
# Finished
# Get Data for :  ZDGE
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ZDGE.csv  Saved
# Finished
# Get Data for :  ZEN
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ZEN.csv  Saved
# Finished
# Get Data for :  Z
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/Z.csv  Saved
# Finished
# Get Data for :  ZG
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ZG.csv  Saved
# Finished
# Get Data for :  ZBH
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ZBH.csv  Saved
# Finished
# Get Data for :  ZN
# - ZN: No data found, symbol may be delisted
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ZN.csv  Saved
# Finished
# Get Data for :  ZION
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ZION.csv  Saved
# Finished
# Get Data for :  ZIOP
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ZIOP.csv  Saved
# Finished
# Get Data for :  ZIXI
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ZIXI.csv  Saved
# Finished
# Get Data for :  ZTS
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ZTS.csv  Saved
# Finished
# Get Data for :  ZGNX
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ZGNX.csv  Saved
# Finished
# Get Data for :  ZM
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ZM.csv  Saved
# Finished
# Get Data for :  ZSAN
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ZSAN.csv  Saved
# Finished
# Get Data for :  ZVO
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ZVO.csv  Saved
# Finished
# Get Data for :  ZS
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ZS.csv  Saved
# Finished
# Get Data for :  ZUMZ
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ZUMZ.csv  Saved
# Finished
# Get Data for :  ZUO
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ZUO.csv  Saved
# Finished
# Get Data for :  ZYNE
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ZYNE.csv  Saved
# Finished
# Get Data for :  ZYXI
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ZYXI.csv  Saved
# Finished
# Get Data for :  ZNGA
# C:/Users/jishm/CodingPractice/Invest/Wilshare_Stocks/ZNGA.csv  Saved
# Finished
